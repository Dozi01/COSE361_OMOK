# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Projects/COSE361_OMOK
# Out:
# /content/drive/MyDrive/Projects/COSE361_OMOK

# %%
# !python train.py --gpu --bs 4096 --play_batch_size 16
# Out:
# Namespace(init_model=None, gpu=True, bs=4096, play_batch_size=16)

# %%
# !python human_play.py
